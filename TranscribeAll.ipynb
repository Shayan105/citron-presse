# %%
import transcript

# %%
#list all files ending with .mp3 in the disk G:
import os
from glob import glob
files_names = glob("G:/**/*.mp3", recursive=True)
print(files_names)
# Out:
# ['G:/31-05-2025.mp3', 'G:/01-04-2025.mp3', 'G:/01-05-2025.mp3', 'G:/01-06-2025.mp3', 'G:/01-07-2025.mp3', 'G:/02-04-2025.mp3', 'G:/02-05-2025.mp3', 'G:/02-06-2025.mp3', 'G:/02-07-2025.mp3', 'G:/03-04-2025.mp3', 'G:/03-05-2025.mp3', 'G:/03-06-2025.mp3', 'G:/03-07-2025.mp3', 'G:/04-04-2025.mp3', 'G:/04-05-2025.mp3', 'G:/04-06-2025.mp3', 'G:/04-07-2025.mp3', 'G:/05-04-2025.mp3', 'G:/05-05-2025.mp3', 'G:/05-06-2025.mp3', 'G:/06-05-2025.mp3', 'G:/06-06-2025.mp3', 'G:/07-04-2025.mp3', 'G:/07-05-2025.mp3', 'G:/07-06-2025.mp3', 'G:/08-04-2025.mp3', 'G:/08-05-2025.mp3', 'G:/08-06-2025.mp3', 'G:/09-04-2025.mp3', 'G:/09-05-2025.mp3', 'G:/09-06-2025.mp3', 'G:/10-04-2025.mp3', 'G:/10-05-2025.mp3', 'G:/10-06-2025.mp3', 'G:/11-04-2025.mp3', 'G:/11-05-2025.mp3', 'G:/11-06-2025.mp3', 'G:/12-04-2025.mp3', 'G:/12-05-2025.mp3', 'G:/12-06-2025.mp3', 'G:/13-04-2025.mp3', 'G:/13-05-2025.mp3', 'G:/13-06-2025.mp3', 'G:/14-04-2025.mp3', 'G:/14-05-2025.mp3', 'G:/14-06-2025.mp3', 'G:/15-04-2025.mp3', 'G:/15-05-
# ...

# %%
dict = {}
i = 0
for file_name in files_names:
    i+=1
    name = file_name.replace("G:/", "")
    topic = transcript.load_daily_topic(file_name)
    dict[name] = topic
    print(f"{name} : {topic} : {i}/{len(files_names)}")
# Out:
# 31-05-2025.mp3 : ?
#  : 1/105
# 01-04-2025.mp3 : Les pâtisseries
#  : 2/105
# 01-05-2025.mp3 : Des cocktails
#  : 3/105
# 01-06-2025.mp3 : Fête des papas
#  : 4/105
# 01-07-2025.mp3 : L'actualité
#  : 5/105
# 02-04-2025.mp3 : Michel Sardou
#  : 6/105
# 02-05-2025.mp3 : cétacés
#  : 7/105
# 02-06-2025.mp3 : Les animaux
#  : 8/105
# 02-07-2025.mp3 : cloche
#  : 9/105
# 03-04-2025.mp3 : RUE
#  : 10/105
# 03-05-2025.mp3 : ?
#  : 11/105
# 03-06-2025.mp3 : autour du mot tomate
#  : 12/105
# 03-07-2025.mp3 : Divers et variés
#  : 13/105
# 04-04-2025.mp3 : Surnom des villes
#  : 14/105
# 04-05-2025.mp3 : ?
#  : 15/105
# 04-06-2025.mp3 : les sorcières
#  : 16/105
# 04-07-2025.mp3 : Les prénoms en K
#  : 17/105
# 05-04-2025.mp3 : Halle des Maçons
#  : 18/105
# 05-05-2025.mp3 : Le sel
#  : 19/105
# 05-06-2025.mp3 : Les présidents des Etats-Unis
#  : 20/105
# 06-05-2025.mp3 : Les oeufs
#  : 21/105
# 06-06-2025.mp3 : Les mots commençant par TA
#  : 22/105
# ...

# %%
dict = {}
file_name = "23-07-2025.mp3"
name = file_name.replace("G:/", "")
topic = transcript.load_daily_topic(file_name)
dict[name] = topic
print(f"{name} : {topic} ")
# Out:
# 23-07-2025.mp3 : football
